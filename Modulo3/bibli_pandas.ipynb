# %% [markdown]
# Uso da biblioteca Pandas

# %%
import drive
drive.mount('/content/drive')

# %%
import pandas as pd

pd.read_excel('/content/drive/MyDrive/Colab Notebooks/ProgrAmo - Analise de Dados/Modulo3/dados.xlsx')
